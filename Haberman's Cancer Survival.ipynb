# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("haberman.csv")
df.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
df.columns =["age", "operation_year","axillary_lymph_node","survival_status"]
df.head()
# Out:
#    age  operation_year  axillary_lymph_node  survival_status
# 0   30              62                    3                1
# 1   30              65                    0                1
# 2   31              59                    2                1
# 3   31              65                    4                1
# 4   33              58                   10                1

# %% [raw]
# Survival status class attribute
# 1 = the patient survived 5 years or longer
# 2 = the patient died witin 5 years

# %%
df.shape
# Out:
# (305, 4)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  305 non-null    int64
#  1   operation_year       305 non-null    int64
#  2   axillary_lymph_node  305 non-null    int64
#  3   survival_status      305 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 9.7+ KB
# None

# %%
df['survival_status'] = df['survival_status'].map({1:"yes", 2:"no"})
df.head()
# Out:
#    age  operation_year  axillary_lymph_node survival_status
# 0   30              62                    3             NaN
# 1   30              65                    0             NaN
# 2   31              59                    2             NaN
# 3   31              65                    4             NaN
# 4   33              58                   10             NaN

# %%
df.describe()
# Out:
#               age  operation_year  axillary_lymph_node
# count  305.000000      305.000000           305.000000
# mean    52.531148       62.849180             4.036066
# std     10.744024        3.254078             7.199370
# min     30.000000       58.000000             0.000000
# 25%     44.000000       60.000000             0.000000
# 50%     52.000000       63.000000             1.000000
# 75%     61.000000       66.000000             4.000000
# max     83.000000       69.000000            52.000000

# %%
df['survival_status'].value_counts()
# Out:
# Series([], Name: survival_status, dtype: int64)

# %%
status_yes = df[df['survival_status']=='yes']
status_yes.describe()
# Out:
#        age  operation_year  axillary_lymph_node
# count  0.0             0.0                  0.0
# mean   NaN             NaN                  NaN
# std    NaN             NaN                  NaN
# min    NaN             NaN                  NaN
# 25%    NaN             NaN                  NaN
# 50%    NaN             NaN                  NaN
# 75%    NaN             NaN                  NaN
# max    NaN             NaN                  NaN

# %%
status_no = df[df['survival_status']=='no']
status_no.describe()
# Out:
#        age  operation_year  axillary_lymph_node
# count  0.0             0.0                  0.0
# mean   NaN             NaN                  NaN
# std    NaN             NaN                  NaN
# min    NaN             NaN                  NaN
# 25%    NaN             NaN                  NaN
# 50%    NaN             NaN                  NaN
# 75%    NaN             NaN                  NaN
# max    NaN             NaN                  NaN

# %% [markdown]
# # 1. Univariant Analysis - Histogram

# %%
fm = sns.FacetGrid(df, hue='survival_status', height=5)
fm.map(sns.histplot,'age')
fm.add_legend()
plt.show()

# %%
fm = sns.FacetGrid(df,hue='survival_status',height=5)
fm.map(sns.distplot,'operation_year')
fm.add_legend()
plt.show()
# Out:
# C:\Users\IMRAN ROSHAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\IMRAN ROSHAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
fm = sns.FacetGrid(df,hue= 'survival_status', height=5)
fm.map(sns.distplot, 'axillary_lymph_node')
fm.add_legend()
plt.show()
# Out:
# C:\Users\IMRAN ROSHAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\IMRAN ROSHAN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
